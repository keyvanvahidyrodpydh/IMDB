# %%
#Importing required libraries
import pandas as pd  #pandas for importing files and rearranging the data
import numpy as np
import seaborn as sb
from scipy import sparse #scipy for math functions

import sys
import pickle
import matplotlib.pyplot as plt
import math
import seaborn as sns
import os
from collections import defaultdict

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
lus= pd.read_excel('train/lu.xls')
lus=lus[['city','country'] ]
lu = pd.DataFrame(lus)
lu
# Out:
#        city  country
# 0        10        3
# 1        10        3
# 2        10        3
# 3        10        3
# 4        10        3
# ...     ...      ...
# 16492    10        3
# 16493    10        3
# 16494    10        3
# 16495    10        3
# 16496    10        3
#
# [16497 rows x 2 columns]

# %%
import xlrd
 
loc = ("train/lu.xls")
 
wb = xlrd.open_workbook(loc)
sheet = wb.sheet_by_index(0)
 
# For row 0 and column 0
sheet.cell_value(0, 0)
 
for i in range(sheet.ncols):
    print(sheet.cell_value(0, i))
# Out:
# city
# country
# lu

# %%
import xlrd
 
loc = ("train/lu.xls")
 
wb = xlrd.open_workbook(loc)
sheet = wb.sheet_by_index(0)
sheet.cell_value(0, 0)
 
for i in range(sheet.nrows):
    for j in range(sheet.ncols):
        print(sheet.cell_value(i, j))
# Out:
# city
# country
# lu
# 10.0
# 3.0
# 0.8
# 10.0
# 3.0
# 0.8
# 10.0
# 3.0
# 0.8
# 10.0
# 3.0
# 0.8
# 10.0
# 3.0
# 0.8
# 10.0
# 3.0
# 0.8
# 10.0
# 3.0
# 0.8
# 10.0
# 3.0
# 0.8
# 10.0
# 3.0
# 0.8
# 10.0
# 3.0
# 0.8
# 10.0
# 3.0
# 0.8
# 10.0
# 3.0
# 0.8
# 10.0
# 3.0
# 0.8
# 10.0
# 3.0
# 0.8
# 10.0
# 3.0
# 0.8
# 10.0
# 3.0
# 0.8
# 10.0
# 3.0
# 0.8
# 10.0
# 3.0
# 0.8
# 10.0
# 3.0
# 0.8
# 10.0
# 3.0
# 0.8
# 10.0
# 3.0
# 0.8
# 10.0
# 3.0
# 0.8
# 10.0
# 3.0
# 0.8
# 10.0
# 3.0
# 0.8
# 10.0
# 3.0
# 0.8
# 10.0
# 3.0
# 0.8
# 10.0
# 3.0
# 0.8
# 10.0
# 3.0
# 0.8
# 10.0
# 3.0
# 0.8
# 10.0
# 3.0
# 0.8
# 10.0
# 3.0
# 0.8
# 10.0
# 3.0
# 0.8
# 10.0
# 3.0
# 0.8
# 10.0
# 3.0
# 0.8
# 10.0
# 3.0
# 0.8
# 10.0
# 3.0
# 0.8
# 10.0
# 3.0
# 0.8
# 10.0
# 3.0
# 0.8
# 10.0
# 3.0
# 0.8
# 10.0
# 3.0
# 0.8
# 10.0
# 3.0
# 0.8
# 10.0
# 3.0
# 0.8
# 10.0
# 3.0
# 0.8
# 10.0
# 3.0
# 0.8
# 10.0
# 3.0
# 0.8
# 10.0
# 3.0
# 0.8
# 10.0
# 3.0
# 0.8
# 10.0
# 3.0
# 0.8
# 10.0
# 3.0
# 0.8
# 10.0
# 3.0
# 0.8
# 10.0
# 3.0
# 0.8
# 10.0
# ...

# %%
#User location city user-context
def LU(lu1 , lu2): 
    if city1 == city2 : 
         return 0.8
    else:
        return 0

# %%
#User location  country user-context
def LU(lu1 , lu2): 
    if country1== country2: 
         return 0.4
    else:
        return 0

# %%
x= range(sheet.ncols)
d= len(x)
d
# Out:
# 3

# %%
 rate  = [eval(input()) , eval(input())  ]
# Out:
# 5
# 1

# %%
rate
# Out:
# [5, 1]

# %%
import openpyxl as xl

wb = xl.load_workbook("train/lu.xlsx")
sheet = wb['loc']


for row in range(2, sheet.max_row):
    for column in range(2, sheet.max_column):    
        lu = lu(sheet.cell(row, column),rate[column])
        lu_cell = sheet.cell(row, 2)
        lu_cell.value=lu
sheet['lu'] = "lu"
wb.save("train/lu.xlsx")

# %%
pd.DataFrame(lu).to_excel('output/outputlu.xlsx', index=False)
