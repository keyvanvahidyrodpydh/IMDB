# %%
# this is just to know how much time will it take to run this entire ipython notebook 
from datetime import datetime
# globalstart = datetime.now()
import pandas as pd
import numpy as np
import matplotlib
matplotlib.use('nbagg')

import matplotlib.pyplot as plt
plt.rcParams.update({'figure.max_open_warning': 0})

import seaborn as sns
sns.set_style('whitegrid')
import os
from scipy import sparse
from scipy.sparse import csr_matrix

from sklearn.decomposition import TruncatedSVD
from sklearn.metrics.pairwise import cosine_similarity
import random

# %% [markdown]
# # import data

# %%
UI = pd.read_csv('data/UI.csv')
UD = pd.read_csv('data/UD.csv')
IF = pd.read_csv('data/IF.csv')
C = pd.read_csv('data/C.csv')

# %%
UD
# Out:
#        userID  age  sex  city  country
# 0          15   30    1    10        3
# 1          15   30    1    10        3
# 2          15   30    1    10        3
# 3          15   30    1    10        3
# 4          15   30    1    10        3
# ...       ...  ...  ...   ...      ...
# 20753    2564   20    2     3        1
# 20754    2564   20    2     3        1
# 20755    2564   20    2     3        1
# 20756    2564   20    2     3        1
# 20757    2564   20    2     3        1
#
# [20758 rows x 5 columns]

# %%
UD.describe()
# Out:
#              userID           age           sex          city       country
# count  20758.000000  20758.000000  20758.000000  20758.000000  20758.000000
# mean    1237.120676     27.234127      1.519848     13.338376      2.193275
# std      742.350765     21.924879      0.499618      6.704369      0.723609
# min       15.000000     -1.000000      1.000000      1.000000      1.000000
# 25%      626.000000     22.000000      1.000000     10.000000      2.000000
# 50%     1255.000000     28.000000      2.000000     10.000000      2.000000
# 75%     1825.000000     30.000000      2.000000     20.000000      3.000000
# max     2568.000000    900.000000      2.000000     22.000000      4.000000

# %%
IF
# Out:
#        itemID  genre1  genre2  genre3  actor1  actor2  actor3
# 0          11       7      18      18     862      61    1378
# 1         214      14      21      17     704    1622     309
# 2         215       1      14      17    1857    1562     939
# 3         216       7      -1      -1     172     513     535
# 4          99       1       3      19    1622     699     497
# ...       ...     ...     ...     ...     ...     ...     ...
# 20753    2509       8      17      21    1772     635     174
# 20754    4016       8      10      21     869     645    1416
# 20755      47       1      17      19    1169    1088     997
# 20756      30       8      10      17     223    1404     699
# 20757     203       7      10      -1     549    1344     893
#
# [20758 rows x 7 columns]

# %%
C
# Out:
#        userID  itemID  time  daytype  season  location  weather  social  \
# 0          15      11     3        1       3         1        1       2
# 1          15     214     3        2       3         1        5       2
# 2          15     215     2        2       3         1        2       2
# 3          15     216     3        1       3         1        5       2
# 4          15      99     3        1       3         1        5       2
# ...       ...     ...   ...      ...     ...       ...      ...     ...
# 20753    2564    2509     4        1       2         1        3       1
# 20754    2564    4016     4        1       1         1        3       1
# 20755    2564      47     2        1       2         2        1       1
# 20756    2564      30     4        1       4         1        5       1
# 20757    2564     203     3        1       3         2        5       3
#
#        endEmo  dominantEmo  mood  physical  decition  interaction  director  \
# ...

# %%
UI
# Out:
#               Id  userID  itemID  rating
# 0       r7989_c1      15      11       4
# 1       r8006_c1      15     214       3
# 2       r8071_c1      15     215       2
# 3       r8180_c1      15     216       4
# 4       r8198_c1      15      99       5
# ...          ...     ...     ...     ...
# 20754  r9463_c68    2564    4016       5
# 20755  r9464_c68    2564      47       4
# 20756  r9465_c68    2564      30       5
# 20757  r9467_c68    2564     203       3
# 20758  r9481_c68      15    3550       3
#
# [20759 rows x 4 columns]

# %%
UI.describe()['userID']
# Out:
# count    20759.000000
# mean      1237.061805
# std        742.381343
# min         15.000000
# 25%        626.000000
# 50%       1255.000000
# 75%       1825.000000
# max       2568.000000
# Name: userID, dtype: float64

# %%
UI.describe()['itemID']
# Out:
# count    20759.000000
# mean      2789.405029
# std       1685.819901
# min          1.000000
# 25%        226.000000
# 50%       3696.000000
# 75%       4006.000000
# max       4381.000000
# Name: itemID, dtype: float64

# %%
UI.describe()['rating']
# Out:
# count    2.075900e+04
# mean     9.352954e+04
# std      2.871679e+06
# min     -1.000000e+00
# 25%      3.000000e+00
# 50%      4.000000e+00
# 75%      5.000000e+00
# max      1.600000e+08
# Name: rating, dtype: float64

# %% [markdown]
# # Checking for NaN values

# %%
print("No of Nan values in our dataframe : ", sum(UI.isnull().any()))
# Out:
# No of Nan values in our dataframe :  0

# %% [markdown]
# # Removing Duplicates

# %%
dup_bool = UI.duplicated(['itemID','userID','rating'])
dups = sum(dup_bool) # by considering all columns..( including timestamp)
print("There are {} duplicate rating entries in the data..".format(dups))
# Out:
# There are 336 duplicate rating entries in the data..

# %% [markdown]
# # Basic Statistics (#Ratings, #Users, and #items)

# %%
print("Total data ")
print("-"*50)
print("\nTotal no of ratings :",UI.shape[0])
print("Total No of Users   :", len(np.unique(UI.userID)))
print("Total No of items  :", len(np.unique(UI.itemID)))
# Out:
# Total data
# --------------------------------------------------
#
# Total no of ratings : 20759
# Total No of Users   : 1061
# Total No of items  : 1231

# %% [markdown]
# # 2 Spliting data into Train and Test(80:20)

# %%
if not os.path.isfile('data/train.csv'):
    # create the dataframe and store it in the disk for offline purposes..
    UI.iloc[:int(UI.shape[0]*0.80)].to_csv("data/train.csv", index=False)

if not os.path.isfile('data/test.csv'):
    # create the dataframe and store it in the disk for offline purposes..
    UI.iloc[int(UI.shape[0]*0.80):].to_csv("data/test.csv", index=False)

train_df = pd.read_csv("data/train.csv")
test_df = pd.read_csv("data/test.csv")

# %% [markdown]
# # Basic Statistics in Train data (#Ratings, #Users, and #items)

# %%
# items = train_df.item.value_counts()
# users = train_df.user.value_counts()
print("Training data ")
print("-"*50)
print("\nTotal no of ratings :",train_df.shape[0])
print("Total No of Users   :", len(np.unique(train_df.userID)))
print("Total No of items  :", len(np.unique(train_df.itemID)))
# Out:
# Training data
# --------------------------------------------------
#
# Total no of ratings : 16607
# Total No of Users   : 798
# Total No of items  : 1231

# %%
# items = test_df.item.value_counts()
# users = test_df.user.value_counts()
print("Test data ")
print("-"*50)
print("\nTotal no of ratings :",test_df.shape[0])
print("Total No of Users   :", len(np.unique(test_df.userID)))
print("Total No of items  :", len(np.unique(test_df.itemID)))
# Out:
# Test data
# --------------------------------------------------
#
# Total no of ratings : 16608
# Total No of Users   : 988
# Total No of items  : 1230

# %% [markdown]
# # 3 Exploratory Data Analysis on Train data

# %%
# method to make y-axis more readable
def human(num, units = 'M'):
    units = units.lower()
    num = float(num)
    if units == 'k':
        return str(num/10) + " K"
    elif units == 'm':
        return str(num/10**2) + " M"
    elif units == 'b':
        return str(num/10**3) +  " B"

# %% [markdown]
# # Distribution of ratings

# %%
fig, ax = plt.subplots()
plt.title('Distribution of ratings over Training dataset', fontsize=15)
sns.countplot(train_df.rating)
ax.set_yticklabels([human(item, 'M') for item in ax.get_yticks()])
ax.set_ylabel('No. of Ratings(Millions)')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# pd.options.mode.chained_assignment = None  # default='warn'
#
# train_df['day_of_week'] = train_df.date.dt.weekday_name
#
# train_df.tail()

# %% [markdown]
# ax = train_df.resample('m', on='date')['rating'].count().plot()
# ax.set_title('No of ratings per month (Training data)')
# plt.xlabel('Month')
# plt.ylabel('No of ratings(per month)')
# ax.set_yticklabels([human(item, 'M') for item in ax.get_yticks()])
# plt.show()

# %% [markdown]
# # Analysis on the Ratings given by user

# %%
no_of_rated_item_per_user = train_df.groupby(by='userID')['rating'].count().sort_values(ascending=False)

no_of_rated_item_per_user.head()
# Out:
# userID
# 955     275
# 1255    275
# 1455    275
# 55      275
# 355     275
# Name: rating, dtype: int64

# %%
fig = plt.figure(figsize=plt.figaspect(.5))

ax1 = plt.subplot(121)
sns.kdeplot(no_of_rated_item_per_user, shade=True, ax=ax1)
plt.xlabel('No of ratings by user')
plt.title("PDF")

ax2 = plt.subplot(122)
sns.kdeplot(no_of_rated_item_per_user, shade=True, cumulative=True,ax=ax2)
plt.xlabel('No of ratings by user')
plt.title('CDF')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="960">

# %%
quantiles = no_of_rated_item_per_user.quantile(np.arange(0,1.01,0.01), interpolation='higher')

# %%
plt.title("Quantiles and their Values")
quantiles.plot()
# quantiles with 0.05 difference
plt.scatter(x=quantiles.index[::5], y=quantiles.values[::5], c='orange', label="quantiles with 0.05 intervals")
# quantiles with 0.25 difference
plt.scatter(x=quantiles.index[::25], y=quantiles.values[::25], c='m', label = "quantiles with 0.25 intervals")
plt.ylabel('No of ratings by user')
plt.xlabel('Value at the quantile')
plt.legend(loc='best')

# annotate the 25th, 50th, 75th and 100th percentile values....
for x,y in zip(quantiles.index[::25], quantiles[::25]):
    plt.annotate(s="({} , {})".format(x,y), xy=(x,y), xytext=(x-0.05, y+500)
                ,fontweight='bold')


plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
quantiles[::5]
# Out:
# 0.00      1
# 0.05      1
# 0.10      1
# 0.15      1
# 0.20      1
# 0.25      1
# 0.30      2
# 0.35      2
# 0.40      3
# 0.45      3
# 0.50      4
# 0.55      5
# 0.60      6
# 0.65      7
# 0.70      9
# 0.75     20
# 0.80     28
# 0.85     36
# 0.90     65
# 0.95    102
# 1.00    275
# Name: rating, dtype: int64

# %% [markdown]
# __how many ratings at the last 5% of all ratings__??

# %%
print('\n No of ratings at last 5 percentile : {}\n'.format(sum(no_of_rated_item_per_user>= 749)) )
# Out:
#  No of ratings at last 5 percentile : 0

# %% [markdown]
# # Analysis of ratings of a item given by a user

# %%
no_of_ratings_per_item = train_df.groupby(by='itemID')['rating'].count().sort_values(ascending=False)

fig = plt.figure(figsize=plt.figaspect(.5))
ax = plt.gca()
plt.plot(no_of_ratings_per_item.values)
plt.title('# RATINGS per item')
plt.xlabel('item')
plt.ylabel('No of Users who rated a item')
ax.set_xticklabels([])

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="960">

# %% [markdown]
# # Number of ratings on each day of the week

# %% [markdown]
# fig, ax = plt.subplots()
# sns.countplot(x='day_of_week', data=train_df, ax=ax)
# plt.title('No of ratings on each day...')
# plt.ylabel('Total no of ratings')
# plt.xlabel('')
# ax.set_yticklabels([human(item, 'M') for item in ax.get_yticks()])
# plt.show()

# %% [markdown]
# start = datetime.now()
# fig = plt.figure(figsize=plt.figaspect(.45))
# sns.boxplot(y='rating', x='day_of_week', data=train_df)
# plt.show()
# print(datetime.now() - start)

# %% [markdown]
# avg_week_df = train_df.groupby(by=['day_of_week'])['rating'].mean()
# print(" AVerage ratings")
# print("-"*30)
# print(avg_week_df)
# print("\n")

# %% [markdown]
# # Creating sparse matrix from data frame

# %%
start = datetime.now()
if os.path.isfile('train_sparse_matrix.npz'):
    print("It is present in your pwd, getting it from disk....")
    # just get it from the disk instead of computing it
    train_sparse_matrix = sparse.load_npz('train_sparse_matrix.npz')
    print("DONE..")
else: 
    print("We are creating sparse_matrix from the dataframe..")
    # create sparse_matrix and store it for after usage.
    # csr_matrix(data_values, (row_index, col_index), shape_of_matrix)
    # It should be in such a way that, MATRIX[row, col] = data
    train_sparse_matrix = sparse.csr_matrix((train_df.rating.values, (train_df.userID.values,
                                               train_df.itemID.values)),)
    
    print('Done. It\'s shape is : (userID, itemID) : ',train_sparse_matrix.shape)
    print('Saving it into disk for furthur usage..')
    # save it into disk
    sparse.save_npz("train_sparse_matrix.npz", train_sparse_matrix)
    print('Done..\n')

print(datetime.now() - start)
# Out:
# It is present in your pwd, getting it from disk....
# DONE..
# 0:00:00.046894

# %% [markdown]
# # The Sparsity of Train Sparse Matrix

# %%
us,mv = train_sparse_matrix.shape
elem = train_sparse_matrix.count_nonzero()

print("Sparsity Of Train matrix : {} % ".format(  (1-(elem/(us*mv))) * 100) )
# Out:
# Sparsity Of Train matrix : 99.84838182515031 %

# %% [markdown]
# # Creating sparse matrix from test data frame

# %%
start = datetime.now()
if os.path.isfile('test_sparse_matrix.npz'):
    print("It is present in your pwd, getting it from disk....")
    # just get it from the disk instead of computing it
    test_sparse_matrix = sparse.load_npz('test_sparse_matrix.npz')
    print("DONE..")
else: 
    print("We are creating sparse_matrix from the dataframe..")
    # create sparse_matrix and store it for after usage.
    # csr_matrix(data_values, (row_index, col_index), shape_of_matrix)
    # It should be in such a way that, MATRIX[row, col] = data
    test_sparse_matrix = sparse.csr_matrix((test_df.rating.values, (test_df.userID.values,
                                               test_df.itemID.values)))
    
    print('Done. It\'s shape is : (userID, itemID) : ',test_sparse_matrix.shape)
    print('Saving it into disk for furthur usage..')
    # save it into disk
    sparse.save_npz("test_sparse_matrix.npz", test_sparse_matrix)
    print('Done..\n')
    
print(datetime.now() - start)
# Out:
# It is present in your pwd, getting it from disk....
# DONE..
# 0:00:00.015625

# %% [markdown]
# # The Sparsity of Test data Matrix

# %%
us,mv = test_sparse_matrix.shape
elem = test_sparse_matrix.count_nonzero()

print("Sparsity Of Test matrix : {} % ".format(  (1-(elem/(us*mv))) * 100) )
# Out:
# Sparsity Of Test matrix : 99.8559786408143 %

# %% [markdown]
# # Finding Global average of all item ratings, Average rating per user, and Average rating per item

# %%
# get the user averages in dictionary (key: userID/movieID, value: avg rating)

def get_average_ratings(sparse_matrix, of_users):
    
    # average ratings of user/axes
    ax = 1 if of_users else 0 # 1 - User axes,0 - item axes

    # ".A1" is for converting Column_Matrix to 1-D numpy array 
    sum_of_ratings = sparse_matrix.sum(axis=ax).A1
    # Boolean matrix of ratings ( whether a user rated that item or not)
    is_rated = sparse_matrix!=0
    # no of ratings that each user OR item..
    no_of_ratings = is_rated.sum(axis=ax).A1
    
    # max_user  and max_movie ids in sparse matrix 
    u,m = sparse_matrix.shape
    # creae a dictonary of users and their average ratigns..
    average_ratings = { i : sum_of_ratings[i]/no_of_ratings[i]
                                 for i in range(u if of_users else m) 
                                    if no_of_ratings[i] !=0}

    # return that dictionary of average ratings
    return average_ratings

# %% [markdown]
# # finding global average of all item ratings

# %%
train_averages = dict()
# get the global average of ratings in our train set.
train_global_average = train_sparse_matrix.sum()/train_sparse_matrix.count_nonzero()
train_averages['global'] = train_global_average
train_averages
# Out:
# {'global': 119473.49153898221}

# %% [markdown]
# # finding average rating per user

# %%
train_averages['userID'] = get_average_ratings(train_sparse_matrix, of_users=True)
print('\nAverage rating of user 10 :',train_averages['userID'])
# Out:
# Average rating of user 10 : {15: 3.910179640718563, 20: 4.4, 21: 3.8920863309352516, 22: 4.0, 23: 4.142857142857143, 24: 4.12, 25: 3.3655913978494625, 26: 3.722772277227723, 27: 3.5, 28: 3.2162162162162162, 29: 3.0, 30: 2.5, 31: 3.784313725490196, 33: 3.395348837209302, 34: 4.0, 35: 3.694736842105263, 37: 3.6875, 38: 3.0, 39: 3.6, 40: 1.0, 41: 3.3333333333333335, 42: 3.6944444444444446, 43: 4.5, 45: 4.5, 47: 3.0, 48: 4.338983050847458, 49: 4.111111111111111, 50: 3.9393939393939394, 52: 4.0, 53: 3.75, 54: 3.90625, 55: 3.7316176470588234, 56: 3.5, 57: 3.2, 59: 2.9411764705882355, 60: 3.84, 61: 4.058252427184466, 62: 5.0, 63: 3.0, 64: 5.0, 71: 4.0, 72: 5.0, 73: 4.507936507936508, 75: 4.507936507936508, 79: 4.5, 82: 5.0, 83: 5.0, 85: 4.5, 86: 4.625, 87: 5.0, 88: 5.0, 89: 3.375, 91: 3.6666666666666665, 93: 5.0, 96: 4.1, 99: 3.0, 100: 3.8333333333333335, 103: 5.0, 104: 2.6666666666666665, 105: 4.0, 108: 5.0, 112: 4.142857142857143, 122: 4.0, 123: 3.0, 125: 4.015384615384615, 126: 5.0, 127:
# ...

# %%
train_averages['itemID'] =  get_average_ratings(train_sparse_matrix, of_users=False)
print('\n AVerage rating of item 15 :',train_averages['itemID'][15])
# Out:
#  AVerage rating of item 15 : 3.9411764705882355

# %% [markdown]
# # PDF's & CDF's of Avg.Ratings of Users & Movies (In Train Data)

# %%
start = datetime.now()
# draw pdfs for average rating per user and average
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=plt.figaspect(.5))
fig.suptitle('Avg Ratings per User and per item', fontsize=15)

ax1.set_title('Users-Avg-Ratings')
# get the list of average user ratings from the averages dictionary..
user_averages = [rat for rat in train_averages['userID'].values()]
sns.distplot(user_averages, ax=ax1, hist=False, 
             kde_kws=dict(cumulative=True), label='Cdf')
sns.distplot(user_averages, ax=ax1, hist=False,label='Pdf')

ax2.set_title('item-Avg-Rating')
# get the list of movie_average_ratings from the dictionary..
item_averages = [rat for rat in train_averages['itemID'].values()]
sns.distplot(item_averages, ax=ax2, hist=False, 
             kde_kws=dict(cumulative=True), label='Cdf')
sns.distplot(item_averages, ax=ax2, hist=False, label='Pdf')

plt.show()
print(datetime.now() - start)
# Out:
# <img src="data:image/png;base64,..." width="960">
# <img src="data:image/png;base64,..." width="960">
# 0:00:00.362891

# %% [markdown]
# # 4.Cold Start problem

# %% [markdown]
# # Cold Start problem with Users

# %%
total_users = len(np.unique(UI.userID))
users_train = len(train_averages['userID'])
new_users = total_users - users_train

print('\nTotal number of Users  :', total_users)
print('\nNumber of Users in Train data :', users_train)
print("\nNo of Users that didn't appear in train data: {}({} %) \n ".format(new_users,
                                                                        np.round((new_users/total_users)*100, 2)))
# Out:
# Total number of Users  : 1061
#
# Number of Users in Train data : 798
#
# No of Users that didn't appear in train data: 263(24.79 %)

# %% [markdown]
# # 4 Computing Similarity matrices

# %% [markdown]
# # Computing User-User Similarity matrix

# %% [markdown]
# 1. Calculating User User Similarity_Matrix is __not very easy__(_unless you have huge Computing Power and lots of time_) because of number of. usersbeing lare.
#
#     * You can try if you want to. Your system could crash or the program stops with **Memory Error**

# %% [markdown]
# Trying with all dimensions (17k dimensions per user)

# %%
from sklearn.metrics.pairwise import cosine_similarity


def compute_user_similarity(sparse_matrix, compute_for_few=False, top = 100, verbose=False, verb_for_n_rows = 20,
                            draw_time_taken=True):
    no_of_users, _ = sparse_matrix.shape
    # get the indices of  non zero rows(users) from our sparse matrix
    row_ind, col_ind = sparse_matrix.nonzero()
    row_ind = sorted(set(row_ind)) # we don't have to
    time_taken = list() #  time taken for finding similar users for an user..
    
    # we create rows, cols, and data lists.., which can be used to create sparse matrices
    rows, cols, data = list(), list(), list()
    if verbose: print("Computing top",top,"similarities for each user..")
    
    start = datetime.now()
    temp = 0
    
    for row in row_ind[:top] if compute_for_few else row_ind:
        temp = temp+1
        prev = datetime.now()
        
        # get the similarity row for this user with all other users
        sim = cosine_similarity(sparse_matrix.getrow(row), sparse_matrix).ravel()
        # We will get only the top ''top'' most similar users and ignore rest of them..
        top_sim_ind = sim.argsort()[-top:]
        top_sim_val = sim[top_sim_ind]
        
        # add them to our rows, cols and data
        rows.extend([row]*top)
        cols.extend(top_sim_ind)
        data.extend(top_sim_val)
        time_taken.append(datetime.now().timestamp() - prev.timestamp())
        if verbose:
            if temp%verb_for_n_rows == 0:
                print("computing done for {} users [  time elapsed : {}  ]"
                      .format(temp, datetime.now()-start))
            
        
    # lets create sparse matrix out of these and return it
    if verbose: print('Creating Sparse matrix from the computed similarities')
    #return rows, cols, data
    
    if draw_time_taken:
        plt.plot(time_taken, label = 'time taken for each user')
        plt.plot(np.cumsum(time_taken), label='Total time')
        plt.legend(loc='best')
        plt.xlabel('User')
        plt.ylabel('Time (seconds)')
        plt.show()
        
    return sparse.csr_matrix((data, (rows, cols)), shape=(no_of_users, no_of_users)), time_taken

# %%
start = datetime.now()
u_u_sim_sparse, _ = compute_user_similarity(train_sparse_matrix, compute_for_few=True, top = 100,
                                                     verbose=True)
print("-"*100)
print("Time taken :",datetime.now()-start)
# Out:
# Computing top 100 similarities for each user..
# computing done for 20 users [  time elapsed : 0:00:00.704919  ]
# computing done for 40 users [  time elapsed : 0:00:00.720529  ]
# computing done for 60 users [  time elapsed : 0:00:00.736162  ]
# computing done for 80 users [  time elapsed : 0:00:00.751728  ]
# computing done for 100 users [  time elapsed : 0:00:00.767412  ]
# Creating Sparse matrix from the computed similarities
# <img src="data:image/png;base64,..." width="640">
# ----------------------------------------------------------------------------------------------------
# Time taken : 0:00:00.805837

# %% [markdown]
# # Trying with reduced dimensions (Using TruncatedSVD for dimensionality reduction of user vector)

# %%
from datetime import datetime
from sklearn.decomposition import TruncatedSVD

start = datetime.now()

# initilaize the algorithm with some parameters..
# All of them are default except n_components. n_itr is for Randomized SVD solver.
IMDB_svd = TruncatedSVD(n_components=500, algorithm='randomized', random_state=15)
trunc_svd = IMDB_svd.fit_transform(train_sparse_matrix)

print(datetime.now()-start)
# Out:
# 0:00:01.968247

# %% [markdown]
# Here,
#
#
# - $\sum \longleftarrow$ (IMDB\_svd.**singular\_values\_** )
#
#
# - $\bigvee^T \longleftarrow$ (IMDB\_svd.**components_**)
#
#
# - $\bigcup$ is not returned. instead **Projection_of_X** onto the new vectorspace is returned.
#
#
# - It uses **randomized svd** internally, which returns **All 3 of them saperately**. Use that instead..

# %%
expl_var = np.cumsum(IMDB_svd.explained_variance_ratio_)

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=plt.figaspect(.5))

ax1.set_ylabel("Variance Explained", fontsize=15)
ax1.set_xlabel("# Latent Facors", fontsize=15)
ax1.plot(expl_var)
# annote some (latentfactors, expl_var) to make it clear
ind = [1, 2,4,8,20, 60, 100, 200, 300, 400, 500]
ax1.scatter(x = [i-1 for i in ind], y = expl_var[[i-1 for i in ind]], c='#ff3300')
for i in ind:
    ax1.annotate(s ="({}, {})".format(i,  np.round(expl_var[i-1], 2)), xy=(i-1, expl_var[i-1]),
                xytext = ( i+20, expl_var[i-1] - 0.01), fontweight='bold')

change_in_expl_var = [expl_var[i+1] - expl_var[i] for i in range(len(expl_var)-1)]
ax2.plot(change_in_expl_var)



ax2.set_ylabel("Gain in Var_Expl with One Additional LF", fontsize=10)
ax2.yaxis.set_label_position("right")
ax2.set_xlabel("# Latent Facors", fontsize=20)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="960">

# %%
for i in ind:
    print("({}, {})".format(i, np.round(expl_var[i-1], 2)))
# Out:
# (1, 0.68)
# (2, 0.93)
# (4, 1.0)
# (8, 1.0)
# (20, 1.0)
# (60, 1.0)
# (100, 1.0)
# (200, 1.0)
# (300, 1.0)
# (400, 1.0)
# (500, 1.0)

# %%
# Let's project our Original U_M matrix into into 500 Dimensional space...
start = datetime.now()
trunc_matrix = train_sparse_matrix.dot(IMDB_svd.components_.T)
print(datetime.now()- start)
# Out:
# 0:00:00.015639

# %%
type(trunc_matrix), trunc_matrix.shape
# Out:
# (numpy.ndarray, (2446, 500))

# %% [markdown]
# * Let's convert this to actual sparse matrix and store it for future purposes

# %%
if not os.path.isfile('trunc_sparse_matrix.npz'):
    # create that sparse sparse matrix
    trunc_sparse_matrix = sparse.csr_matrix(trunc_matrix)
    # Save this truncated sparse matrix for later usage..
    sparse.save_npz('trunc_sparse_matrix', trunc_sparse_matrix)
else:
    trunc_sparse_matrix = sparse.load_npz('trunc_sparse_matrix.npz')

# %%
trunc_sparse_matrix.shape
# Out:
# (2446, 500)

# %%
start = datetime.now()
trunc_u_u_sim_matrix, _ = compute_user_similarity(trunc_sparse_matrix, compute_for_few=True, top=50, verbose=True, 
                                                 verb_for_n_rows=10)
print("-"*50)
print("time:",datetime.now()-start)
# Out:
# Computing top 50 similarities for each user..
# computing done for 10 users [  time elapsed : 0:00:00.203028  ]
# computing done for 20 users [  time elapsed : 0:00:00.324246  ]
# computing done for 30 users [  time elapsed : 0:00:00.440926  ]
# computing done for 40 users [  time elapsed : 0:00:00.557627  ]
# computing done for 50 users [  time elapsed : 0:00:00.675167  ]
# Creating Sparse matrix from the computed similarities
# <img src="data:image/png;base64,..." width="640">
# --------------------------------------------------
# time: 0:00:00.872722

# %% [markdown]
# # Computing item-item Similarity matrix

# %%
start = datetime.now()
if not os.path.isfile('m_m_sim_sparse.npz'):
    print("It seems you don't have that file. Computing item_item similarity...")
    start = datetime.now()
    m_m_sim_sparse = cosine_similarity(X=train_sparse_matrix.T, dense_output=False)
    print("Done..")
    # store this sparse matrix in disk before using it. For future purposes.
    print("Saving it to disk without the need of re-computing it again.. ")
    sparse.save_npz("m_m_sim_sparse.npz", m_m_sim_sparse)
    print("Done..")
else:
    print("It is there, We will get it.")
    m_m_sim_sparse = sparse.load_npz("m_m_sim_sparse.npz")
    print("Done ...")

print("It's a ",m_m_sim_sparse.shape," dimensional matrix")

print(datetime.now() - start)
# Out:
# It is there, We will get it.
# Done ...
# It's a  (4382, 4382)  dimensional matrix
# 0:00:00.015622

# %%
m_m_sim_sparse.shape
# Out:
# (4382, 4382)

# %%
item_ids = np.unique(m_m_sim_sparse.nonzero()[1])

# %% [markdown]
# # Finding most similar items using similarity matrix

# %% [markdown]
# __ Does Similarity really works as the way we expected...? __ <br>
# _Let's pick some random item and check for its similar item ...._

# %%
IF
# Out:
#        itemID  genre1  genre2  genre3  actor1  actor2  actor3
# 0          11       7      18      18     862      61    1378
# 1         214      14      21      17     704    1622     309
# 2         215       1      14      17    1857    1562     939
# 3         216       7      -1      -1     172     513     535
# 4          99       1       3      19    1622     699     497
# ...       ...     ...     ...     ...     ...     ...     ...
# 20753    2509       8      17      21    1772     635     174
# 20754    4016       8      10      21     869     645    1416
# 20755      47       1      17      19    1169    1088     997
# 20756      30       8      10      17     223    1404     699
# 20757     203       7      10      -1     549    1344     893
#
# [20758 rows x 7 columns]

# %%
item_title = pd.read_csv("data/C.csv")

# %%
item_title
# Out:
#        userID  itemID  time  daytype  season  location  weather  social  \
# 0          15      11     3        1       3         1        1       2
# 1          15     214     3        2       3         1        5       2
# 2          15     215     2        2       3         1        2       2
# 3          15     216     3        1       3         1        5       2
# 4          15      99     3        1       3         1        5       2
# ...       ...     ...   ...      ...     ...       ...      ...     ...
# 20753    2564    2509     4        1       2         1        3       1
# 20754    2564    4016     4        1       1         1        3       1
# 20755    2564      47     2        1       2         2        1       1
# 20756    2564      30     4        1       4         1        5       1
# 20757    2564     203     3        1       3         2        5       3
#
#        endEmo  dominantEmo  mood  physical  decition  interaction  director  \
# ...

# %% [markdown]
# # Similar Items

# %%
item_id = 67

print("\nitem ----->",item_title.loc[item_id].values[1])

print("\nIt has {} Ratings from users.".format(train_sparse_matrix[:,item_id].getnnz()))

print("\nWe have {} items which are similarto this  and we will get only top most..".format(m_m_sim_sparse[:,item_id].getnnz()))
# Out:
# item -----> 4028
#
# It has 31 Ratings from users.
#
# We have 388 items which are similarto this  and we will get only top most..

# %%
similarities = m_m_sim_sparse[item_id].toarray().ravel()

similar_indices = similarities.argsort()[::-1][1:]

similarities[similar_indices]

sim_indices = similarities.argsort()[::-1][1:]

# %%
plt.plot(similarities[sim_indices], label='All the ratings')
plt.plot(similarities[sim_indices[:100]], label='top 100 similar items')
plt.title("Similar items of {}(item_id)".format(item_id), fontsize=20)
plt.xlabel("Items (Not item_Ids)", fontsize=15)
plt.ylabel("Cosine Similarity",fontsize=15)
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
item_title.loc[sim_indices[:10]]
# Out:
#       userID  itemID  time  daytype  season  location  weather  social  \
# 135       15     196     4        3       4         2        5       7
# 3797     333    3654     3        1       3         1        5       1
# 3687    1231    4378     2        1       2         1        2       1
# 115       15    4302     3        2       1         1        1       1
# 3029     331     108     3        2       4         1        2       1
# 3632    1231    4106     4        1       3         3        5       6
# 3967     933    3567     2        1       3         1        2       1
# 3634    1231    3686     3        2       3         1        5       1
# 3633    1231    4135     3        1       3         1        5       1
# 3930     633      31     2        1       4         1        5       1
#
#       endEmo  dominantEmo  mood  physical  decition  interaction  director  \
# 135        7            7     3         2         2            2       112
# ...

# %% [markdown]
#  Similarly, we can ___find similar users___ and compare how similar they are.

# %% [markdown]
# # 4.  Machine Learning Models

# %%
def get_sample_sparse_matrix(sparse_matrix, no_users, no_items, path, verbose = True):


    # get (row, col) and (rating) tuple from sparse_matrix...
    row_ind, col_ind, ratings = sparse.find(sparse_matrix)
    users = np.unique(row_ind)
    items = np.unique(col_ind)

    print("Original Matrix : (users, items) -- ({} {})".format(len(users), len(items)))
    print("Original Matrix : Ratings -- {}\n".format(len(ratings)))

    # It just to make sure to get same sample everytime we run this program..
    # and pick without replacement....
    np.random.seed(15)
    sample_users = np.random.choice(users, no_users, replace=False)
    sample_items = np.random.choice(items, no_items, replace=False)
    # get the boolean mask or these sampled_items in originl row/col_inds..
    mask = np.logical_and( np.isin(row_ind, sample_users),
                      np.isin(col_ind, sample_items) )
    
    sample_sparse_matrix = sparse.csr_matrix((ratings[mask], (row_ind[mask], col_ind[mask])),
                                             shape=(max(sample_users)+1, max(sample_items)+1))

    if verbose:
        print("Sampled Matrix : (users, movies) -- ({} {})".format(len(sample_users), len(sample_items)))
        print("Sampled Matrix : Ratings --", format(ratings[mask].shape[0]))

    print('Saving it into disk for furthur usage..')
    # save it into disk
    sparse.save_npz(path, sample_sparse_matrix)
    if verbose:
            print('Done..\n')
    
    return sample_sparse_matrix

# %% [markdown]
# # Sampling Data

# %% [markdown]
# Build sample train data from the train data

# %% [markdown]
# # Build sample test data from the test data

# %% [markdown]
# # Finding Global Average of all item ratings, Average rating per User, and Average rating per Movie (from sampled train

# %% [markdown]
# # Finding Global Average of all movie ratings

# %% [markdown]
# # Featurizing data

# %% [markdown]
# # Featurizing data for regression problem

# %% [markdown]
# Featurizing train data

# %% [markdown]
# Reading from the file to make a Train_dataframe

# %% [markdown]
# # 4.1.Matrix Factorization Techniques

# %% [markdown]
# SVD Matrix Factorization User Movie intractions

# %%
from surprise import SVD
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-97-64df1e8420ad> in <module>
# ----> 1 from surprise import SVD
#
# ~\IMDB\surprise\__init__.py in <module>
#       1 from pkg_resources import get_distribution
#       2
# ----> 3 from .prediction_algorithms import AlgoBase
#       4 from .prediction_algorithms import NormalPredictor
#       5 from .prediction_algorithms import BaselineOnly
#
# ~\IMDB\surprise\prediction_algorithms\__init__.py in <module>
#      21 """
#      22
# ---> 23 from .algo_base import AlgoBase
#      24 from .random_pred import NormalPredictor
#      25 from .baseline_only import BaselineOnly
#
# ~\IMDB\surprise\prediction_algorithms\algo_base.py in <module>
#       8                         unicode_literals)
#       9
# ---> 10 from .. import similarities as sims
#      11 from .predictions import PredictionImpossible
# ...

# %% [markdown]
# - __ Predicted Rating : __
#     -
#     - $ \large  \hat r_{ui} = \mu + b_u + b_i + q_i^Tp_u $
#
#         - $\pmb q_i$ - Representation of item(movie) in latent factor space
#
#         - $\pmb p_u$ - Representation of user in new latent factor space

# %% [markdown]
# - __Optimization problem with user item interactions and regularization (to avoid overfitting)__
#     -
#     - $\large \sum_{r_{ui} \in R_{train}} \left(r_{ui} - \hat{r}_{ui} \right)^2 +
# \lambda\left(b_i^2 + b_u^2 + ||q_i||^2 + ||p_u||^2\right) $

# %%
# initiallize the model
svd = SVD(n_factors=100, biased=True, random_state=15, verbose=True)
svd_train_results, svd_test_results = run_surprise(svd, trainset, testset, verbose=True)

# Just store these error metrics in our models_evaluation datastructure
models_evaluation_train['svd'] = svd_train_results 
models_evaluation_test['svd'] = svd_test_results
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-99-a795106a7d71> in <module>
#       1 # initiallize the model
# ----> 2 svd = SVD(n_factors=100, biased=True, random_state=15, verbose=True)
#       3 svd_train_results, svd_test_results = run_surprise(svd, trainset, testset, verbose=True)
#       4
#       5 # Just store these error metrics in our models_evaluation datastructure
#
# NameError: name 'SVD' is not defined

# %% [markdown]
# # SVD Matrix Factorization with implicit feedback from user ( user rated movies )

# %% [markdown]
# - __ Predicted Rating : __
#     -
#     - $ \large \hat{r}_{ui} = \mu + b_u + b_i + q_i^T\left(p_u +
#     |I_u|^{-\frac{1}{2}} \sum_{j \in I_u}y_j\right) $

# %% [markdown]
# - __Optimization problem with user item interactions and regularization (to avoid overfitting)__
#     -
#     - $ \large \sum_{r_{ui} \in R_{train}} \left(r_{ui} - \hat{r}_{ui} \right)^2 +
# \lambda\left(b_i^2 + b_u^2 + ||q_i||^2 + ||p_u||^2 + ||y_j||^2\right) $
